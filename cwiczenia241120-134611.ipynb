# %%
# %matplotlib inline

# %% [markdown]
# **Simple visualization and classification of the digits dataset**
# =============================================================
#
# Do a simple MLP classification of 28x28 MNIST dataset
#
# *Marcin Wolter*

# %%
#import packages and load datasets

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.model_selection import train_test_split


# Load data from https://www.openml.org/d/554
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X / 255.


# split the data into training and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33, train_size=0.5)

# %% [markdown]
# Plot the data: images of digits
# -------------------------------
#
# Each data in a 28x28 image
#
# ![digits_1.png](data:image/png;base64,...)

# %%
# leave empty for time beeing

# %% [markdown]
# ## **Classify with MLP**

# %%
# tu musimy zdefiniować klasyfikator, wytrenowaći sprawdzić "score" dla 
# danych testowych
#Proponowane parametry sieci: ukryte warstwy [100,100],solver adam, verbose=10 
clf = MLPClassifier(hidden_layer_sizes=(10,10), solver='adam', verbose=10, validation_fraction=0.2, early_stopping=True)
                     
print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# use the model to predict the labels of the test data
predicted = clf.predict(X_test)
expected = y_test
# Out:
# Iteration 1, loss = 1.62432384
# Validation score: 0.704143
# Iteration 2, loss = 0.65146857
# Validation score: 0.855571
# Iteration 3, loss = 0.42875262
# Validation score: 0.878143
# Iteration 4, loss = 0.36671528
# Validation score: 0.891286
# Iteration 5, loss = 0.33401691
# Validation score: 0.899143
# Iteration 6, loss = 0.31040230
# Validation score: 0.908286
# Iteration 7, loss = 0.29409157
# Validation score: 0.909571
# Iteration 8, loss = 0.28063654
# Validation score: 0.915857
# Iteration 9, loss = 0.26898378
# Validation score: 0.915857
# Iteration 10, loss = 0.26035317
# Validation score: 0.920857
# Iteration 11, loss = 0.25284720
# Validation score: 0.922571
# Iteration 12, loss = 0.24622865
# Validation score: 0.921143
# Iteration 13, loss = 0.24093190
# Validation score: 0.923143
# Iteration 14, loss = 0.23447333
# Validation score: 0.921571
# Iteration 15, loss = 0.23095471
# Validation score: 0.924714
# Iteration 16, loss = 0.22647946
# Validation score: 0.925857
# Iteration 17, loss = 0.22200230
# Validation score: 0.924857
# Iteration 18, loss = 0.21909351
# Validation score: 0.926143
# Iteration 19, loss = 0.21614674
# Validation score: 0.925143
# Iteration 20, loss = 0.21184776
# Validation score: 0.926143
# Iteration 21, loss = 0.21092037
# Validation score: 0.928714
# Iteration 22, loss = 0.20611838
# Validation score: 0.927000
# Iteration 23, loss = 0.20453012
# Validation score: 0.928143
# Iteration 24, loss = 0.20269206
# Validation score: 0.926429
# Iteration 25, loss = 0.19863865
# Validation score: 0.930857
# Iteration 26, loss = 0.19676321
# Validation score: 0.926714
# Iteration 27, loss = 0.19566018
# Validation score: 0.929857
# Iteration 28, loss = 0.19202960
# Validation score: 0.925286
# Iteration 29, loss = 0.19284739
# Validation score: 0.928714
# Iteration 30, loss = 0.18811285
# Validation score: 0.928429
# Iteration 31, loss = 0.18645692
# Validation score: 0.927286
# Iteration 32, loss = 0.18433166
# Validation score: 0.927857
# Iteration 33, loss = 0.18282018
# Validation score: 0.928143
# Iteration 34, loss = 0.18107971
# Validation score: 0.930000
# Iteration 35, loss = 0.17908905
# Validation score: 0.930429
# Iteration 36, loss = 0.17725749
# Validation score: 0.928571
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(10, 10), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=10,
#               warm_start=False)
# Score =  0.9246285714285715

# %% [markdown]
# # **Plot loss**
# ![loss_1.png](data:image/png;base64,...)

# %%
# tu rysujemy loss i validation score
# zostawiamy na razie puste
fig=plt.figure(figsize=(7,7))

plt.plot(clf.loss_curve_)
#Warning: thiscan be usedonly if early_stopping=True
print(clf.validation_scores_)
plt.plot(np.asarray(clf.validation_scores_))

plt.show()
# Out:
# [0.7041428571428572, 0.8555714285714285, 0.8781428571428571, 0.8912857142857142, 0.8991428571428571, 0.9082857142857143, 0.9095714285714286, 0.9158571428571428, 0.9158571428571428, 0.9208571428571428, 0.9225714285714286, 0.9211428571428572, 0.9231428571428572, 0.9215714285714286, 0.9247142857142857, 0.9258571428571428, 0.9248571428571428, 0.9261428571428572, 0.9251428571428572, 0.9261428571428572, 0.9287142857142857, 0.927, 0.9281428571428572, 0.9264285714285714, 0.9308571428571428, 0.9267142857142857, 0.9298571428571428, 0.9252857142857143, 0.9287142857142857, 0.9284285714285714, 0.9272857142857143, 0.9278571428571428, 0.9281428571428572, 0.93, 0.9304285714285714, 0.9285714285714286]

# %% [markdown]
# #**Plot results**
# ![digits_2.png](data:image/png;base64,...)

# %%
# Plot the prediction

# Tu rysujemy cyfry z wynikami
# na razie zostawiamy puste

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(15, 15)) # figure size in inches
 
for i in range(25):
 ax = fig.add_subplot(5, 5, i + 1)
 ax.imshow(X_test[i].reshape(28,28), cmap=plt.cm.gray, interpolation='nearest')
 if expected[i]==predicted[i]:
    ax.text(0, 7, str(expected[i])+" "+str(predicted[i]), color='white')
 else:
    ax.text(0, 7, str(expected[i])+" "+str(predicted[i]), color='red')

# %% [markdown]
# Print the classification report

# %%
#from sklearn import metrics
#print(metrics.classification_report(expected, predicted))

# %% [markdown]
# # **Print the confusion matrix (expected true label vs. the reconstructed label)**

# %%
#print(metrics.confusion_matrix(expected, predicted))

# %% [markdown]
# # **Repeat the same classification for faces**

# %%
####################################################
# Load dataset with faces
from sklearn.datasets import fetch_lfw_people

# #############################################################################
# Download the data, if not already on disk and load it as numpy arrays

lfw_people = fetch_lfw_people(min_faces_per_person=100, resize=0.50)  
print(lfw_people.images.shape)


# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape

# for machine learning we use the 2 data directly (as relative pixel
# positions info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# the label to predict is the id of the person
y = lfw_people.target
# to get real names, not digits
target_names = lfw_people.target_names

# split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

print("Image shape: ",X_train.shape)
# dimension of face image
nfaces, h, w = lfw_people.images.shape
print("Image shape: ", h, w)
# Out:
# (904, 62, 47)
# Image shape:  (678, 2914)
# Image shape:  62 47

# %% [markdown]
# Plot the data: images of faces
# -------------------------------
#
# Each data in a 32x24 image
#
# ![faces_1.png](data:image/png;base64,...)

# %%
#import packages and load datasets

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.model_selection import train_test_split

# tu rysujemy twarze
# tu rysujemy twarze
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 16)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
 
for i in range(100):
 ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
 ax.imshow(X_test[i].reshape(h,w), cmap=plt.cm.gray, interpolation='nearest')
 # label the image with the target value
 ax.text(0, 7, str(target_names[y_test[i]]))

# %% [markdown]
# ## **Classify with MLP**

# %%
# train the model
# tu musimy zdefiniować klasyfikator, wytrenowaći sprawdzić "score" dla 
# danych testowych
#Proponowane parametry sieci: ukryte warstwy [100,100],solver adam, verbose=10 
clf = MLPClassifier(hidden_layer_sizes=(100,100), solver='adam', alpha=0.1, verbose=10, validation_fraction=0.2, early_stopping=True,n_iter_no_change=50)
                     
print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# Validation score: 0.772059
# Iteration 107, loss = 0.43230729
# Validation score: 0.772059
# Iteration 108, loss = 0.38466704
# Validation score: 0.742647
# Iteration 109, loss = 0.38399670
# Validation score: 0.786765
# Iteration 110, loss = 0.33685888
# Validation score: 0.808824
# Iteration 111, loss = 0.33090050
# Validation score: 0.772059
# Iteration 112, loss = 0.26640035
# Validation score: 0.816176
# Iteration 113, loss = 0.29705221
# Validation score: 0.794118
# Iteration 114, loss = 0.29901986
# Validation score: 0.764706
# Iteration 115, loss = 0.29243410
# Validation score: 0.801471
# Iteration 116, loss = 0.35473150
# Validation score: 0.757353
# Iteration 117, loss = 0.27719817
# Validation score: 0.823529
# Iteration 118, loss = 0.30623198
# Validation score: 0.779412
# Iteration 119, loss = 0.31861075
# Validation score: 0.808824
# Iteration 120, loss = 0.39889678
# Validation score: 0.772059
# Iteration 121, loss = 0.31171143
# Validation score: 0.794118
# Iteration 122, loss = 0.24955449
# Validation score: 0.816176
# Iteration 123, loss = 0.24082514
# Validation score: 0.779412
# Iteration 124, loss = 0.23219616
# Validation score: 0.823529
# Iteration 125, loss = 0.22899218
# Validation score: 0.794118
# Iteration 126, loss = 0.20908499
# Validation score: 0.816176
# Iteration 127, loss = 0.19482069
# Validation score: 0.779412
# Iteration 128, loss = 0.21905305
# Validation score: 0.816176
# Iteration 129, loss = 0.17670199
# Validation score: 0.786765
# Iteration 130, loss = 0.19739687
# Validation score: 0.816176
# Iteration 131, loss = 0.17647172
# Validation score: 0.779412
# Iteration 132, loss = 0.19163320
# Validation score: 0.816176
# Iteration 133, loss = 0.15387624
# Validation score: 0.816176
# Iteration 134, loss = 0.15721331
# Validation score: 0.808824
# Iteration 135, loss = 0.15234474
# Validation score: 0.808824
# Iteration 136, loss = 0.14193110
# Validation score: 0.823529
# Iteration 137, loss = 0.14418200
# Validation score: 0.816176
# Iteration 138, loss = 0.14289491
# Validation score: 0.808824
# Iteration 139, loss = 0.13597560
# Validation score: 0.816176
# Iteration 140, loss = 0.14414154
# Validation score: 0.808824
# Iteration 141, loss = 0.14796913
# Validation score: 0.794118
# Iteration 142, loss = 0.19919220
# Validation score: 0.764706
# Iteration 143, loss = 0.18289357
# Validation score: 0.779412
# Iteration 144, loss = 0.19492946
# Validation score: 0.808824
# Iteration 145, loss = 0.16862664
# Validation score: 0.794118
# Iteration 146, loss = 0.15688973
# Validation score: 0.808824
# Iteration 147, loss = 0.21776850
# Validation score: 0.801471
# Validation score did not improve more than tol=0.000100 for 50 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(100, 100), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=200,
#               momentum=0.9, n_iter_no_change=50, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=10,
#               warm_start=False)
# Score =  0.8008849557522124

# %% [markdown]
# # **Plot loss**

# %%
# tu rysujemy loss i validation score
# zostawiamy na razie puste
fig=plt.figure(figsize=(7,7))

plt.plot(clf.loss_curve_)
#Warning: thiscan be usedonly if early_stopping=True
print(clf.validation_scores_)
plt.plot(np.asarray(clf.validation_scores_))

plt.show()
# Out:
# [0.6176470588235294, 0.6176470588235294, 0.15441176470588236, 0.19852941176470587, 0.25735294117647056, 0.6176470588235294, 0.16911764705882354, 0.4338235294117647, 0.19852941176470587, 0.5441176470588235, 0.16176470588235295, 0.6029411764705882, 0.5882352941176471, 0.11029411764705882, 0.625, 0.6029411764705882, 0.6176470588235294, 0.6176470588235294, 0.6470588235294118, 0.16911764705882354, 0.6176470588235294, 0.16176470588235295, 0.23529411764705882, 0.4632352941176471, 0.6176470588235294, 0.34558823529411764, 0.6323529411764706, 0.3897058823529412, 0.625, 0.5735294117647058, 0.6617647058823529, 0.5661764705882353, 0.6838235294117647, 0.6617647058823529, 0.5882352941176471, 0.6838235294117647, 0.5147058823529411, 0.6617647058823529, 0.6176470588235294, 0.7058823529411765, 0.6691176470588235, 0.6029411764705882, 0.6985294117647058, 0.7205882352941176, 0.7205882352941176, 0.7058823529411765, 0.7132352941176471, 0.7058823529411765, 0.7352941176470589, 0.6617647058823529, 0.7720588235294118, 0.7352941176470589, 0.7426470588235294, 0.7279411764705882, 0.7647058823529411, 0.7058823529411765, 0.7867647058823529, 0.7352941176470589, 0.7426470588235294, 0.7720588235294118, 0.7647058823529411, 0.8014705882352942, 0.6911764705882353, 0.7426470588235294, 0.75, 0.75, 0.5882352941176471, 0.6764705882352942, 0.7058823529411765, 0.7279411764705882, 0.6029411764705882, 0.6544117647058824, 0.5441176470588235, 0.7132352941176471, 0.7058823529411765, 0.6691176470588235, 0.7426470588235294, 0.5882352941176471, 0.7794117647058824, 0.7941176470588235, 0.5220588235294118, 0.49264705882352944, 0.625, 0.7867647058823529, 0.7426470588235294, 0.6691176470588235, 0.7941176470588235, 0.7352941176470589, 0.7132352941176471, 0.7205882352941176, 0.7794117647058824, 0.7941176470588235, 0.7647058823529411, 0.7941176470588235, 0.7573529411764706, 0.8235294117647058, 0.7647058823529411, 0.8088235294117647, 0.7352941176470589, 0.7647058823529411, 0.8014705882352942, 0.7720588235294118, 0.7867647058823529, 0.8161764705882353, 0.7573529411764706, 0.7720588235294118, 0.7720588235294118, 0.7426470588235294, 0.7867647058823529, 0.8088235294117647, 0.7720588235294118, 0.8161764705882353, 0.7941176470588235, 0.7647058823529411, 0.8014705882352942, 0.7573529411764706, 0.8235294117647058, 0.7794117647058824, 0.8088235294117647, 0.7720588235294118, 0.7941176470588235, 0.8161764705882353, 0.7794117647058824, 0.8235294117647058, 0.7941176470588235, 0.8161764705882353, 0.7794117647058824, 0.8161764705882353, 0.7867647058823529, 0.8161764705882353, 0.7794117647058824, 0.8161764705882353, 0.8161764705882353, 0.8088235294117647, 0.8088235294117647, 0.8235294117647058, 0.8161764705882353, 0.8088235294117647, 0.8161764705882353, 0.8088235294117647, 0.7941176470588235, 0.7647058823529411, 0.7794117647058824, 0.8088235294117647, 0.7941176470588235, 0.8088235294117647, 0.8014705882352942]

# %% [markdown]
# # **Plot results**

# %% [markdown]
# ![faces_2.png](data:image/png;base64,...)

# %%
# Plot the prediction
#import packages and load datasets

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.model_selection import train_test_split

# tu rysujemy twarze
# tu rysujemy twarze
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 16)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
 
for i in range(100):
 ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
 ax.imshow(X_test[i].reshape(h,w), cmap=plt.cm.gray, interpolation='nearest')
 # label the image with the target value
 if expected[i]==predicted[i]:
    ax.text(0, 7, str(target_names[expected[i]])+" \n"+str(target_names[predicted[i]]), color='black')
 else:
     ax.text(0, 7, str(target_names[expected[i]])+" \n"+str(target_names[predicted[i]]), color='red')

# %% [markdown]
# Print the classification report

# %%
#from sklearn import metrics
#print(metrics.classification_report(expected, predicted))

# %% [markdown]
# # **Print the confusion matrix (expected true label vs. the reconstructed label)**

# %%
#print(metrics.confusion_matrix(expected, predicted))
